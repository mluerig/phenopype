# %% [markdown]
# # Example 3: setting landmarks and drawing lines

# %% [markdown]
# Functional morphology of organisms is often measured by placing landmarks at specific points that show structural, functional or developmental significance. In this example phenopype is used to place morphometric landmarks across the anterior half of a stickleback (*G. aculeatus*) stained with alizarin red.
#
#
#
# |Raw image|Output|
# |:---|:---|
# | <img src="../assets/images/stickleback_side.JPG" width="300"/>||
# | <img src="../assets/images/stickleback_top.JPG" width="300"/>||

# %% [markdown]
# ## 1. Default workflow
# This

# %%
import phenopype as pp

# %%
img, df_image_data = pp.load_image(r"../assets/images/stickleback.JPG", df=True, meta=True)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Invalid image path - cannot load image from str.
# WARNING: To exit: use 'exit', 'quit', or Ctrl-D.
